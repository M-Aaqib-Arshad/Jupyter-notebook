# %% [markdown]
# ## Line Plot

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ship = sns.load_dataset("titanic")
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# import Libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

point = sns.load_dataset("dots")

point.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# import Libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

point = sns.load_dataset("dots")

# defining a color palette
pel = sns.color_palette('rocket_r')

# Line Plot
sns.relplot(data=point,x='time',y="firing_rate",
          hue="coherence", size="choice",col="align",palette=pel,
          kind="line", size_order=["T1","T2"],height=5,aspect=.75,
           facet_kws=dict(sharex=False))
plt.show()

# %%
#libraries
import seaborn as sns
import matplotlib.pyplot as plt
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")

sns.boxplot(x="day", y="total_bill", hue="smoker",data=tip,
           palette=["m","g"],dodge=True) 
# Dodge=smoker plot side by side
sns.despine(offset=10,trim=True)
 
plt.show()

# %%
#libraries
import seaborn as sns
import matplotlib.pyplot as plt
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
tip = sns.load_dataset("tips")

sns.violinplot(x="day", y="total_bill", hue="smoker",data=tip,split=True,
           palette={"Yes":"b","No":".85"},inner="quart",linewidth=1) 
# Dodge=smoker plot side by side
sns.despine(left=True)
 
plt.show()

# %%
#libraries
import seaborn as sns
import matplotlib.pyplot as plt
# use to set style of background of plot
sns.set(style="whitegrid")

# loading data-set
diamonds = sns.load_dataset("diamonds")

f,ax = plt.subplots(figsize=(6.5,6.5))

sns.despine(f,left=True,bottom=True)
clarity_ranking =["I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF"]
sns.scatterplot(x="carat", y="price", hue="clarity",data=diamonds,
                size="depth",
           palette="ch:r=-.2,d=.3_r",hue_order=clarity_ranking,
                sizes=(1,8),linewidth=0,ax=ax) 
# Dodge=smoker plot side by side
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df,hue="species")
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/examples/index.html
